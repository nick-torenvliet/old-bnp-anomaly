# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt

data_dir = [0]

for d in data_dir:
    All_files = sorted(glob('/home/torenvln/git/bnp-anomaly/data/fail/' + str(d) + '/*.csv'))
    print(All_files)
    headers = ('x','y')
    for file in All_files:
        name = file.split('.csv')[0]
        df = pd.read_csv(file, names=headers)
        x,y = df['x'], df['y']
        fig, ax = plt.subplots(figsize=(7,4))
        ax.plot(x,y)
        plt.tight_layout()
        plt.title(file)
        #plt.savefig(name+'.png', dpi=300, bbox='tight')
        plt.show()
# Out:
# ['/home/torenvln/git/bnp-anomaly/data/fail/0/fail_01.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_02.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_03.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_04.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_05.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_06.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_07.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_08.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_09.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_10.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_11.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_12.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_13.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_14.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_15.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_16.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_17.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_18.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_19.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_20.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_21.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_22.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_23.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_24.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_25.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_26.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_27.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_28.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_29.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_30.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_31.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_32.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_33.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_34.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_35.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_36.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_37.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_38.csv', '/home/torenvln/git/bnp-anomaly/data/fail/0/fail_39.csv']
