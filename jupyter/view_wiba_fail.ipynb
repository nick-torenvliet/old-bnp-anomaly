# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt

data_dir = [7]

for d in data_dir:
    All_files = sorted(glob('/home/torenvln/git/bnp-anomaly/data/fail/' + str(d) + '/*.csv'))
    print(All_files)
    headers = ('x','y')
    for file in All_files:
        name = file.split('.csv')[0]
        df = pd.read_csv(file, names=headers)
        x,y = df['x'], df['y']
        fig, ax = plt.subplots(figsize=(7,4))
        ax.plot(x,y)
        plt.tight_layout()
        plt.title(file)
        #plt.savefig(name+'.png', dpi=300, bbox='tight')
        plt.show()
# Out:
# ['/home/torenvln/git/bnp-anomaly/data/fail/7/7_01.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_02.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_03.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_04.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_05.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_06.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_07.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_08.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_09.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_10.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_11.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_12.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_13.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_14.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_15.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_16.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_17.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_18.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_19.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_20.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_21.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_22.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_23.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_24.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_25.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_26.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_27.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_28.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_29.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_30.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_31.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_32.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_33.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_34.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_35.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_36.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_37.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_38.csv', '/home/torenvln/git/bnp-anomaly/data/fail/7/7_39.csv']
