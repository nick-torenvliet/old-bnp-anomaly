# %%
import h5py
import pandas as pd
data_file = [
                "/home/torenvln/4-2019_ai0453.hdf5",
                "/home/torenvln/4-2019_ai3652.hdf5",
                "/home/torenvln/4-2019_ai3241.hdf5",
                "/home/torenvln/4-2019_ai3050.hdf5",
                "/home/torenvln/4-2019_ai0612.hdf5",
                "/home/torenvln/4-2019_ai0543.hdf5"]
for i,file in enumerate(data_file):
    f = h5py.File(file, 'r' ) 
    tag = list(f.keys())[0]
    df = pd.DataFrame(f.get(tag+"/eng_val"))
    df.to_csv("/home/torenvln/git/bnp-anomaly/data/" + str(i) + ".csv")

# %%
import h5py
import pandas as pd
index = [1,2,3,4,5]
data_file = [
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai0245.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai0251.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai3061.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7127.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7544.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7626.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7642.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7733.hdf5"
]
for i in index:
    print(i, data_file[i])
    f = h5py.File(data_file[i], 'r' ) 
    print(f)
    tag = list(f.keys())[0]
    print(tag)
    df = pd.DataFrame(f.get(tag+"/eng_val"))
    df.to_csv("/home/torenvln/git/bnp-anomaly/data/fail_" + str(i) + ".csv")
# Out:
# 0 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai0245.hdf5
# <HDF5 file "4-2019_ai0245.hdf5" (mode r)>
# 4-63106-FT39@ai0245
# 1 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai0251.hdf5
# <HDF5 file "4-2019_ai0251.hdf5" (mode r)>
# 4-63106-FT33@ai0251
# 2 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai3061.hdf5
# <HDF5 file "4-2019_ai3061.hdf5" (mode r)>
# 4-63106-TT69@ai3061
# 3 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai7127.hdf5
# <HDF5 file "4-2019_ai7127.hdf5" (mode r)>
# 4-63102-TT352@ai7127
# 4 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai7544.hdf5
# <HDF5 file "4-2019_ai7544.hdf5" (mode r)>
# 4-63102-TT134@ai7544
# 5 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai7626.hdf5
# <HDF5 file "4-2019_ai7626.hdf5" (mode r)>
# 4-63102-TT291@ai7626
# 6 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai7642.hdf5
# <HDF5 file "4-2019_ai7642.hdf5" (mode r)>
# 4-63102-TT234@ai7642
# 7 /home/torenvln/git/data_repo/wiba_failures/4-2019_ai7733.hdf5
# ...
