# %%
import h5py
import pandas as pd
data_file = [
                "/home/torenvln/4-2019_ai0453.hdf5",
                "/home/torenvln/4-2019_ai3652.hdf5",
                "/home/torenvln/4-2019_ai3241.hdf5",
                "/home/torenvln/4-2019_ai3050.hdf5",
                "/home/torenvln/4-2019_ai0612.hdf5",
                "/home/torenvln/4-2019_ai0543.hdf5"]
for i,file in enumerate(data_file):
    f = h5py.File(file, 'r' ) 
    tag = list(f.keys())[0]
    df = pd.DataFrame(f.get(tag+"/eng_val"))
    df.to_csv("/home/torenvln/git/bnp-anomaly/data/" + str(i) + ".csv")

# %%
import h5py
import pandas as pd
data_file = [
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai0245.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai0251.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai3061.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7127.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7544.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7626.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7642.hdf5",
                "/home/torenvln/git/data_repo/wiba_failures/4-2019_ai7733.hdf5"
]
for i,file in enumerate(data_file):
    f = h5py.File(file, 'r' ) 
    tag = list(f.keys())[0]
    df = pd.DataFrame(f.get(tag+"/eng_val"))
    df.to_csv("/home/torenvln/git/bnp-anomaly/data/fail_" + str(i) + ".csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-efd4f6804d35> in <module>
#      14     f = h5py.File(file, 'r' )
#      15     tag = list(f.keys())[0]
# ---> 16     df = pd.DataFrame(f.get(tag+"/eng_val"))
#      17     df.to_csv("/home/torenvln/git/bnp-anomaly/data/fail_" + str(i) + ".csv")
#
# ~/git/interpreters/p3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     467         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     468             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 469                 data = list(data)
#     470             if len(data) > 0:
#     471                 if is_list_like(data[0]) and getattr(data[0], "ndim", 1) == 1:
#
# ~/git/interpreters/p3/lib/python3.6/site-packages/h5py/_hl/dataset.py in __iter__(self)
#     472             raise TypeError("Can't iterate over a scalar dataset")
#     473         for i in xrange(shape[0]):
# --> 474             yield self[i]
#     475
#     476     @with_phil
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/git/interpreters/p3/lib/python3.6/site-packages/h5py/_hl/dataset.py in __getitem__(self, args)
#     536         # === Scalar dataspaces =================
#     537
# --> 538         if self.shape == ():
#     539             fspace = self.id.get_space()
#     540             selection = sel2.select_read(fspace, args)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/git/interpreters/p3/lib/python3.6/site-packages/h5py/_hl/dataset.py in shape(self)
#     284     def shape(self):
#     285         """Numpy-style shape tuple giving dataset dimensions"""
# --> 286         return self.id.shape
#     287     @shape.setter
#     288     @with_phil
#
# KeyboardInterrupt:
